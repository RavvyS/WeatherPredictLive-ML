# %%
import pandas as pd

# %%
weather=pd.read_csv("/Users/ravindusandun/Downloads/weather.csv",index_col="DATE")

# %%
weather.apply(pd.isnull).sum()
# Out:
# STATION        0
# NAME           0
# ACMH       10559
# ACSH       10558
# AWND        5145
# FMTM       10050
# PGTM        7840
# PRCP           0
# SNOW           0
# SNWD           1
# TAVG       13123
# TMAX           0
# TMIN           0
# TSUN       20143
# WDF1       10563
# WDF2        9647
# WDF5        9730
# WDFG       15053
# WDFM       20173
# WESD       14103
# WSF1       10560
# WSF2        9647
# WSF5        9731
# WSFG       12711
# WSFM       20173
# WT01       12756
# WT02       18859
# WT03       18828
# WT04       19823
# WT05       19810
# WT06       19991
# WT07       20066
# WT08       16212
# WT09       20034
# WT11       20160
# WT13       17989
# WT14       19287
# WT15       20132
# WT16       13597
# WT17       20114
# WT18       19007
# WT19       20173
# WT21       20169
# WT22       20125
# WV01       20173
# dtype: int64

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.54
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.32
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  11.41
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  13.42
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
# ...

# %%
null_pct=weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
weather.apply(pd.isnull).sum()
# Out:
# STATION        0
# NAME           0
# ACMH       10559
# ACSH       10558
# AWND        5145
# FMTM       10050
# PGTM        7840
# PRCP           0
# SNOW           0
# SNWD           1
# TAVG       13123
# TMAX           0
# TMIN           0
# TSUN       20143
# WDF1       10563
# WDF2        9647
# WDF5        9730
# WDFG       15053
# WDFM       20173
# WESD       14103
# WSF1       10560
# WSF2        9647
# WSF5        9731
# WSFG       12711
# WSFM       20173
# WT01       12756
# WT02       18859
# WT03       18828
# WT04       19823
# WT05       19810
# WT06       19991
# WT07       20066
# WT08       16212
# WT09       20034
# WT11       20160
# WT13       17989
# WT14       19287
# WT15       20132
# WT16       13597
# WT17       20114
# WT18       19007
# WT19       20173
# WT21       20169
# WT22       20125
# WV01       20173
# dtype: int64

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.523396
# ACSH       0.523347
# AWND       0.255031
# FMTM       0.498166
# PGTM       0.388619
# PRCP       0.000000
# SNOW       0.000000
# SNWD       0.000050
# TAVG       0.650491
# TMAX       0.000000
# TMIN       0.000000
# TSUN       0.998463
# WDF1       0.523595
# WDF2       0.478190
# WDF5       0.482304
# WDFG       0.746158
# WDFM       0.999950
# WESD       0.699068
# WSF1       0.523446
# WSF2       0.478190
# WSF5       0.482354
# WSFG       0.630068
# WSFM       0.999950
# WT01       0.632299
# WT02       0.934817
# WT03       0.933280
# WT04       0.982601
# WT05       0.981957
# WT06       0.990929
# WT07       0.994647
# WT08       0.803609
# WT09       0.993060
# WT11       0.999306
# WT13       0.891692
# WT14       0.956033
# WT15       0.997918
# WT16       0.673986
# WT17       0.997026
# WT18       0.942153
# WT19       0.999950
# WT21       0.999752
# WT22       0.997571
# WV01       0.999950
# ...

# %%
valid_columns= weather.columns[null_pct < .05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather=weather[valid_columns].copy()

# %%
weather.columns=weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.83   0.0   0.0
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
#
#             tmax  tmin
# DATE
# ...

# %%
weather=weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2025-03-17', '2025-03-18', '2025-03-19', '2025-03-20', '2025-03-21',
#        '2025-03-22', '2025-03-23', '2025-03-24', '2025-03-25', '2025-03-26'],
#       dtype='object', name='DATE', length=20174)

# %%
weather.index=pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2025-03-17', '2025-03-18', '2025-03-19', '2025-03-20',
#                '2025-03-21', '2025-03-22', '2025-03-23', '2025-03-24',
#                '2025-03-25', '2025-03-26'],
#               dtype='datetime64[ns]', name='DATE', length=20174, freq=None)

# %%
weather.index.year
# Out:
# Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#        ...
#        2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025, 2025],
#       dtype='int32', name='DATE', length=20174)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    366
# 2025     85
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.83   0.0   0.0
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
#
#             tmax  tmin
# DATE
# ...

# %%
weather["target"]=weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.83   0.0   0.0
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
weather=weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.83   0.0   0.0
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
# !pip install scikit-learn

# %%
from sklearn.linear_model import Ridge
rr = Ridge(alpha=.1)

# %%
predictors=weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
import pandas as pd

def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []

    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i, :]
        test = weather.iloc[i:(i + step), :]

        model.fit(train[predictors], train["target"])  # Train model
        preds = model.predict(test[predictors])  # Predict

        # Create a DataFrame for actual vs. predictions
        combined = pd.DataFrame({"actual": test["target"], "prediction": preds}, index=test.index)
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()

        all_predictions.append(combined)

    return pd.concat(all_predictions) if all_predictions else pd.DataFrame()  # Ensure function doesn't fail on empty input

# %%
predictions = backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2025-03-22    48.0   57.188494   9.188494
# 2025-03-23    50.0   47.777806   2.222194
# 2025-03-24    61.0   51.771533   9.228467
# 2025-03-25    54.0   59.804740   5.804740
# 2025-03-26    54.0   54.064224   0.064224
#
# [16524 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 5.132220597085148

# %%
predictions["diff"].mean()
# Out:
# np.float64(5.132220597085148)

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"

    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}__pct"] = pct_diff(weather[label], weather[col])
    return weather

rolling_horizons =[3, 14]

for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather =compute_rolling(weather, horizon, col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.83   0.0   0.0
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
#
# ...

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.83   0.0   0.0
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
#
# ...

# %%
weather=weather.fillna(0)

# %% [raw]
# def expand_mean(df):
#     return df.expanding(1).mean()
#
# for col in ["tmax","tmin","prcp"]:
#     weather[f"month_avg_{col}"]=weather[col].groupby(weather.index.month, group_keys=False).apply(expand_mean)
#     weather[f"day_avg_{col}"]=weather[col].groupby(weather.index.day_of_year, group_keys=False).apply(expand_mean)
#     #addinf more column like aboce we can modify

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2025-03-22  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-23  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-24  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.83   0.0   0.0
# 2025-03-25  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2025-03-26  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
#
# ...

# %%
predictors=weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax__pct', 'rolling_3_tmin', 'rolling_3_tmin__pct',
#        'rolling_3_prcp', 'rolling_3_prcp__pct', 'rolling_14_tmax',
#        'rolling_14_tmax__pct', 'rolling_14_tmin', 'rolling_14_tmin__pct',
#        'rolling_14_prcp', 'rolling_14_prcp__pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather,rr,predictors)

# %%
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 4.782560605792442

# %%
predictions.sort_values("diff",ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.361065  30.638935
# 2007-03-26    78.0   49.965413  28.034587
# 1998-03-26    80.0   51.966675  28.033325
# 2003-04-15    86.0   59.432179  26.567821
# 1985-04-18    84.0   58.425960  25.574040
# ...            ...         ...        ...
# 1987-09-16    75.0   75.001185   0.001185
# 1984-08-10    83.0   82.999179   0.000821
# 2011-09-25    78.0   77.999237   0.000763
# 1999-09-28    77.0   76.999245   0.000755
# 1984-12-24    47.0   46.999514   0.000486
#
# [16510 rows x 3 columns]

# %%
weather.loc["1990-03-03":"1990-03-21"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.21   1.9   1.0
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>

# %%
#we can create a littlt plot that indicates how often we fall into each error bucket so we can take our diff columnand the n we
